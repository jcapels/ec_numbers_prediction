# %%
import pandas as pd

pd.read_csv("data/swiss_prot_ec_plants.csv").shape
# Out:
# (15519, 7)

# %%
import pandas as pd

pd.read_csv("data/trembl_prot_ec_plants.csv").shape
# Out:
# (1527550, 7)

# %%
import pandas as pd

pd.read_csv("swiss_prot_ec_plants_sm.csv").shape
# Out:
# (1625, 7)

# %%
import pandas as pd

pd.read_csv("trembl_prot_ec_plants_sm.csv").shape
# Out:
# (101736, 7)
