# %%
import torch

weights = torch.load("protbert_no_plants.ckpt")

# %%
pretrained_dict = {k.replace("fc_model.", ""): v for k, v in weights["state_dict"].items()}
pretrained_dict
# Out:
# {'fc_initial.weight': tensor([[ 0.0529,  0.0276,  0.0618,  ...,  0.0050, -0.0164,  0.0658],
#          [-0.0001,  0.0594, -0.0898,  ..., -0.0247,  0.0454,  0.0417],
#          [ 0.0519, -0.0763,  0.0056,  ...,  0.0179,  0.0034, -0.0735],
#          ...,
#          [-0.0265,  0.0284, -0.0434,  ...,  0.0031, -0.0202,  0.0242],
#          [-0.0065, -0.0078, -0.0074,  ..., -0.0157,  0.0138,  0.0008],
#          [ 0.0179, -0.0037,  0.0069,  ..., -0.0632,  0.0137,  0.0245]]),
#  'fc_initial.bias': tensor([-0.0315, -0.0235, -0.0263,  ...,  0.0022, -0.0211, -0.0216]),
#  'batch_norm_initial.weight': tensor([1.6513, 1.6141, 1.6463,  ..., 1.6804, 1.7265, 1.7754]),
#  'batch_norm_initial.bias': tensor([-0.1925, -0.1864, -0.1916,  ..., -0.2003, -0.2072, -0.1210]),
#  'batch_norm_initial.running_mean': tensor([-0.0568,  0.0732,  0.0153,  ...,  0.0402,  0.0224,  0.0195]),
#  'batch_norm_initial.running_var': tensor([0.0011, 0.0013, 0.0011,  ..., 0.0011, 0.0017, 0.0014]),
# ...
